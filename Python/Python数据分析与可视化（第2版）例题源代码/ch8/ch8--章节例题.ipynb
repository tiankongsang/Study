# %% [markdown]
# 【例8-1】利用Bar绘制柱状图。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
# V1 版本开始支持链式调用
bar = ( Bar()
       .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", 
"高跟鞋", "袜子"])
       .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
       .set_global_opts(title_opts = opts.TitleOpts(title = "某商场销售情况")) )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b3fcbf45180e41bd847847e5d1263b98" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b3fcbf45180e41bd847847e5d1263b98 = echarts.init(
#                     document.getElementById('b3fcbf45180e41bd847847e5d1263b98'), 'white', {renderer: 'canvas'});
#                 var option_b3fcbf45180e41bd847847e5d1263b98 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b3fcbf45180e41bd847847e5d1263b98.setOption(option_b3fcbf45180e41bd847847e5d1263b98);
#         });
#     </script>

# %% [markdown]
# 【例8-2】并列柱状图绘制。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
bar.set_global_opts(title_opts = opts.TitleOpts(title = "货品销售情况",subtitle  =  "A和B公司"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8b9c2fcd1a84424986306d1a9f2f6512" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8b9c2fcd1a84424986306d1a9f2f6512 = echarts.init(
#                     document.getElementById('8b9c2fcd1a84424986306d1a9f2f6512'), 'white', {renderer: 'canvas'});
#                 var option_8b9c2fcd1a84424986306d1a9f2f6512 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8d27\u54c1\u9500\u552e\u60c5\u51b5",
#             "subtext": "A\u548cB\u516c\u53f8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8b9c2fcd1a84424986306d1a9f2f6512.setOption(option_8b9c2fcd1a84424986306d1a9f2f6512);
#         });
#     </script>

# %% [markdown]
# 【例8-3】绘制水平直方图。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
bar.set_global_opts(title_opts=opts.TitleOpts(title="货品销售情况",subtitle = "A和B公司"),toolbox_opts = opts.ToolboxOpts(is_show = True))
bar.set_series_opts(label_opts=opts.LabelOpts(position = "right"))
bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1e783f24ca1040c59a5890457660461a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1e783f24ca1040c59a5890457660461a = echarts.init(
#                     document.getElementById('1e783f24ca1040c59a5890457660461a'), 'white', {renderer: 'canvas'});
#                 var option_1e783f24ca1040c59a5890457660461a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8d27\u54c1\u9500\u552e\u60c5\u51b5",
#             "subtext": "A\u548cB\u516c\u53f8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "xAxisIndex": false,
#                 "yAxisIndex": false,
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             },
#             "brush": {
#                 "icon": {},
#                 "title": {
#                     "rect": "\u77e9\u5f62\u9009\u62e9",
#                     "polygon": "\u5708\u9009",
#                     "lineX": "\u6a2a\u5411\u9009\u62e9",
#                     "lineY": "\

# %% [markdown]
# 【例8-4】饼图绘制。

# %%
# from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
L1=['教授','副教授','讲师','助教','其他']
num  = [20,30,10,12,8]
c = Pie()
c.add("", [list(z) for z in zip(L1,num)])
c.set_global_opts(title_opts=opts.TitleOpts(title="Pie-职称类别比例"))
c.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d1618592d25d4c18a9cfad05957a1387" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d1618592d25d4c18a9cfad05957a1387 = echarts.init(
#                     document.getElementById('d1618592d25d4c18a9cfad05957a1387'), 'white', {renderer: 'canvas'});
#                 var option_d1618592d25d4c18a9cfad05957a1387 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6559\u6388",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u526f\u6559\u6388",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8bb2\u5e08",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u52a9\u6559",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 8
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6559\u6388",
#                 "\u526f\u6559\u6388",
#                 "\u8bb2\u5e08",
#                 "\u52a9\u6559",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u804c\u79f0\u7c7b\u522b\u6bd4\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d1618592d25d4c18a9cfad05957a1387.setOption(option_d1618592d25d4c18a9cfad05957a1387);
#         });
#     </script>

# %% [markdown]
# 【例8-5】圆形饼图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c = Pie()
c.add("",[list(z) for z in zip(wd, num)],radius = ["40%", "75%"])   
# 圆环的粗细和大小
c.set_global_opts( title_opts=opts.TitleOpts(title="Pie-Radius"),legend_opts=opts.LegendOpts( orient="vertical", pos_top="5%", pos_left="2%" ))
c .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="46898cd4fc7e460991f5e5f400ffe6e8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_46898cd4fc7e460991f5e5f400ffe6e8 = echarts.init(
#                     document.getElementById('46898cd4fc7e460991f5e5f400ffe6e8'), 'white', {renderer: 'canvas'});
#                 var option_46898cd4fc7e460991f5e5f400ffe6e8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6559\u6388",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u526f\u6559\u6388",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8bb2\u5e08",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u52a9\u6559",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 8
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6559\u6388",
#                 "\u526f\u6559\u6388",
#                 "\u8bb2\u5e08",
#                 "\u52a9\u6559",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "5%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-Radius",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_46898cd4fc7e460991f5e5f400ffe6e8.setOption(option_46898cd4fc7e460991f5e5f400ffe6e8);
#         });
#     </script>

# %% [markdown]
# 【例8-6】圆形饼图中的rich参数应用。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c = Pie()
c.add("",[list(z) for z in zip(wd, num)],radius=["40%", "55%"],
       label_opts=opts.LabelOpts(position="outside",
       formatter="{a|{a}}{abg|}\n{hr|}\n{b|{b}:}{c}  {per|{d}%} ",
       background_color="#eee",border_color="#aaa",
       border_width=1,border_radius=4,
       rich={"a": {"color": "#999", "lineHeight": 22, "align": 
"center"},"abg": {"backgroundColor": "#e3e3e3","width": "100%", "align": "right", "height": 22,"borderRadius": [4, 4, 0, 0],}, "hr": {"borderColor": "#aaa", "width": "100%",
"borderWidth": 0.5, "height": 0,}, "b": {"fontSize": 16, "lineHeight": 33},"per": {"color": "#eee",
"backgroundColor": "#334455",                        "padding": [2, 4],"borderRadius": 2,} } ))
c.set_global_opts(title_opts=opts.TitleOpts(title="Pie-富文本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="171b455e92b745c0a38853cf38a1787d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_171b455e92b745c0a38853cf38a1787d = echarts.init(
#                     document.getElementById('171b455e92b745c0a38853cf38a1787d'), 'white', {renderer: 'canvas'});
#                 var option_171b455e92b745c0a38853cf38a1787d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6559\u6388",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u526f\u6559\u6388",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8bb2\u5e08",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u52a9\u6559",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 8
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{a|{a}}{abg|}\n{hr|}\n{b|{b}:}{c}  {per|{d}%} ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6559\u6388",
#                 "\u526f\u6559\u6388",
#                 "\u8bb2\u5e08",
#                 "\u52a9\u6559",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u5bcc\u6587\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_171b455e92b745c0a38853cf38a1787d.setOption(option_171b455e92b745c0a38853cf38a1787d);
#         });
#     </script>

# %% [markdown]
# 【例8-7】玫瑰图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
data1 = [45,86,39,52,68]
data2 = [67,36,64,89,123]
labels = ['电脑','手机','彩电','冰箱','洗衣机']
c = Pie()
c.add("",[list(z) for z in zip(labels, data1)],radius=["35%", "70%"],center=[180,220],rosetype='radius')
c.add("",[list(z) for z in zip(labels, data2)],radius=["35%", "70%"],center=[550,220],rosetype='area')
c.set_global_opts(title_opts=opts.TitleOpts(title="玫瑰图"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="660cf8c8f496486bafb93c64b6c036a5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_660cf8c8f496486bafb93c64b6c036a5 = echarts.init(
#                     document.getElementById('660cf8c8f496486bafb93c64b6c036a5'), 'white', {renderer: 'canvas'});
#                 var option_660cf8c8f496486bafb93c64b6c036a5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7535\u8111",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u5f69\u7535",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u51b0\u7bb1",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u6d17\u8863\u673a",
#                     "value": 68
#                 }
#             ],
#             "radius": [
#                 "35%",
#                 "70%"
#             ],
#             "center": [
#                 180,
#                 220
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7535\u8111",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5f69\u7535",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u51b0\u7bb1",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u6d17\u8863\u673a",
#                     "value": 123
#                 }
#             ],
#             "radius": [
#                 "35%",
#                 "70%"
#             ],
#             "center": [
#                 550,
#                 220
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u8111",
#                 "\u624b\u673a",
#                 "\u5f69\u7535",
#                 "\u51b0\u7bb1",
#                 "\u6d17\u8863\u673a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u73ab\u7470\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_660cf8c8f496486bafb93c64b6c036a5.setOption(option_660cf8c8f496486bafb93c64b6c036a5);
#         });
#     </script>

# %% [markdown]
# 【例8-8】漏斗图绘制。

# %%
from pyecharts.charts import Funnel
from pyecharts import options as opts
# %matplotlib inline
data = [45,86,39,52,68]
labels = ['电脑','手机','彩电','冰箱','洗衣机']
wf = Funnel()
wf.add('电器销量图',[list(z) for z in zip(labels, data)], is_selected= True)
wf.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="083fef14e414450281a93db7ad181729" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_083fef14e414450281a93db7ad181729 = echarts.init(
#                     document.getElementById('083fef14e414450281a93db7ad181729'), 'white', {renderer: 'canvas'});
#                 var option_083fef14e414450281a93db7ad181729 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u7535\u5668\u9500\u91cf\u56fe",
#             "data": [
#                 {
#                     "name": "\u7535\u8111",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u5f69\u7535",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u51b0\u7bb1",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u6d17\u8863\u673a",
#                     "value": 68
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u8111",
#                 "\u51b0\u7bb1",
#                 "\u6d17\u8863\u673a",
#                 "\u5f69\u7535",
#                 "\u624b\u673a"
#             ],
#             "selected": {
#                 "\u7535\u8111": true,
#                 "\u624b\u673a": true,
#                 "\u5f69\u7535": true,
#                 "\u51b0\u7bb1": true,
#                 "\u6d17\u8863\u673a": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_083fef14e414450281a93db7ad181729.setOption(option_083fef14e414450281a93db7ad181729);
#         });
#     </script>

# %% [markdown]
# 【例8-9】散点图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
week = ["周一", "周二", "周三", "周四", "周五", "周六", "周日"]
c = Scatter()
c.add_xaxis(week)
#c.add_xaxis(Faker.choose())
#c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家A", [81,65,48,32,68,92,87])
c.set_global_opts(title_opts=opts.TitleOpts(title="Scatter-一周的销售额（万元）"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="acb9e1a0864343879e74bb3613c6cc8c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_acb9e1a0864343879e74bb3613c6cc8c = echarts.init(
#                     document.getElementById('acb9e1a0864343879e74bb3613c6cc8c'), 'white', {renderer: 'canvas'});
#                 var option_acb9e1a0864343879e74bb3613c6cc8c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     81
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     65
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     48
#                 ],
#                 [
#                     "\u5468\u56db",
#                     32
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     68
#                 ],
#                 [
#                     "\u5468\u516d",
#                     92
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     87
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u4e00\u5468\u7684\u9500\u552e\u989d\uff08\u4e07\u5143\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_acb9e1a0864343879e74bb3613c6cc8c.setOption(option_acb9e1a0864343879e74bb3613c6cc8c);
#         });
#     </script>

# %% [markdown]
# 例8-10】K线图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Kline
data = [[2320.26, 2320.26, 2287.3, 2362.94],
        [2300, 2291.3, 2288.26, 2308.38],
        [2295.35, 2346.5, 2295.35, 2345.92],
        [2347.22, 2358.98, 2337.35, 2363.8], 
        [2360.75, 2382.48, 2347.89, 2383.76],
        [2383.43, 2385.42, 2371.23, 2391.82],
        [2377.41, 2419.02, 2369.57, 2421.15],
        [2425.92, 2428.15, 2417.58, 2440.38],
        [2411, 2433.13, 2403.3, 2437.42],
        [2432.68, 2334.48, 2427.7, 2441.73],
        [2430.69, 2418.53, 2394.22, 2433.89],
        [2416.62, 2432.4, 2414.4, 2443.03],  
        [2441.91, 2421.56, 2418.43, 2444.8],
        [2420.26, 2382.91, 2373.53, 2427.07],   
        [2383.49, 2397.18, 2370.61, 2397.94],
        [2378.82, 2325.95, 2309.17, 2378.82], 
        [2322.94, 2314.16, 2308.76, 2330.88],
        [2320.62, 2325.82, 2315.01, 2338.78],  
        [2313.74, 2293.34, 2289.89, 2340.71],
        [2297.77, 2313.22, 2292.03, 2324.63], 
        [2322.32, 2365.59, 2308.92, 2366.16],
        [2364.54, 2359.51, 2330.86, 2369.65], 
        [2332.08, 2273.4, 2259.25, 2333.54], 
        [2274.81, 2326.31, 2270.1, 2328.14], 
        [2333.61, 2347.18, 2321.6, 2351.44], 
        [2340.44, 2324.29, 2304.27, 2352.02], 
        [2326.42, 2318.61, 2314.59, 2333.67],
        [2314.68, 2310.59, 2296.58, 2320.96], 
        [2309.16, 2286.6, 2264.83, 2333.29], 
        [2282.17, 2263.97, 2253.25, 2286.33], 
        [2255.77, 2270.28, 2253.31, 2276.22] ]
c = Kline()
c.add_xaxis(["2019/7/{}".format(i + 1) for i in range(31)])
c.add_yaxis("2019年7月份K线图", data)
c.set_global_opts(yaxis_opts=opts.AxisOpts(is_scale=True),
            xaxis_opts=opts.AxisOpts(is_scale=True),
            title_opts=opts.TitleOpts(title="Kline-基本示例"),)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="38d4b14e84cb44ce8189c3a733d175a8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_38d4b14e84cb44ce8189c3a733d175a8 = echarts.init(
#                     document.getElementById('38d4b14e84cb44ce8189c3a733d175a8'), 'white', {renderer: 'canvas'});
#                 var option_38d4b14e84cb44ce8189c3a733d175a8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "2019\u5e747\u6708\u4efdK\u7ebf\u56fe",
#             "data": [
#                 [
#                     2320.26,
#                     2320.26,
#                     2287.3,
#                     2362.94
#                 ],
#                 [
#                     2300,
#                     2291.3,
#                     2288.26,
#                     2308.38
#                 ],
#                 [
#                     2295.35,
#                     2346.5,
#                     2295.35,
#                     2345.92
#                 ],
#                 [
#                     2347.22,
#                     2358.98,
#                     2337.35,
#                     2363.8
#                 ],
#                 [
#                     2360.75,
#                     2382.48,
#                     2347.89,
#                     2383.76
#                 ],
#                 [
#                     2383.43,
#                     2385.42,
#                     2371.23,
#                     2391.82
#                 ],
#                 [
#                     2377.41,
#                     2419.02,
#                     2369.57,
#                     2421.15
#                 ],
#                 [
#                     2425.92,
#                     2428.15,
#                     2417.58,
#                     2440.38
#                 ],
#                 [
#                     2411,
#                     2433.13,
#                     2403.3,
#                     2437.42
#                 ],
#                 [
#                     2432.68,
#                     2334.48,
#                     2427.7,
#                     2441.73
#                 ],
#                 [
#                     2430.69,
#                     2418.53,
#                     2394.22,
#                     2433.89
#                 ],
#                 [
#                     2416.62,
#                     2432.4,
#                     2414.4,
#                     2443.03
#                 ],
#                 [
#                     2441.91,
#                     2421.56,
#                     2418.43,
#                     2444.8
#                 ],
#                 [
#                     2420.26,
#                     2382.91,
#                     2373.53,
#                     2427.07
#                 ],
#                 [
#                     2383.49,
#                     2397.18,
#                     2370.61,
#                     2397.94
#                 ],
#                 [
#                     2378.82,
#                     2325.95,
#                     2309.17,
#                     2378.82
#                 ],
#                 [
#                     2322.94,
#                     2314.16,
#                     2308.76,
#                     2330.88
#                 ],
#                 [
#                     2320.62,
#                     2325.82,
#                     2315.01,
#                     2338.78
#                 ],
#                 [
#                     2313.74,
#                     2293.34,
#                     2289.89,
#                     2340.71
#                 ],
#                 [
#                     2297.77,
#                     2313.22,
#                     2292.03,
#                     2324.63
#                 ],
#                 [
#                     2322.32,
#                     2365.59,
#                     2308.92,
#                     2366.16
#                 ],
#                 [
#                     2364.54,
#                     2359.51,
#                     2330.86,
#                     2369.65
#                 ],
#                 [
#                     2332.08,
#                     2273.4,
#                     2259.25,
#                     2333.54
#                 ],
#                 [
#                     2274.81,
#                     2326.31,
#                     2270.1,
#                     2328.14
#                 ],
#                 [
#                     2333.61,
#                     2347.18,
#                     2321.6,
#                     2351.44
#                 ],
#                 [
#                     2340.44,
#                     2324.29,
#                     2304.27,
#                     2352.02
#                 ],
#                 [
#                     2326.42,
#                     2318.61,
#                     2314.59,
#                     2333.67
#                 ],
#                 [
#                     2314.68,
#                     2310.59,
#                     2296.58,
#                     2320.96
#                 ],
#                 [
#                     2309.16,
#                     2286.6,
#                     2264.83,
#                     2333.29
#                 ],
#                 [
#                     2282.17,
#                     2263.97,
#                     2253.25,
#                     2286.33
#                 ],
#                 [
#                     2255.77,
#                     2270.28,
#                     2253.31,
#                     2276.22
#                 ]
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2019\u5e747\u6708\u4efdK\u7ebf\u56fe"
#             ],
#             "selected": {
#                 "2019\u5e747\u6708\u4efdK\u7ebf\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2019/7/1",
#                 "2019/7/2",
#                 "2019/7/3",
#                 "2019/7/4",
#                 "2019/7/5",
#                 "2019/7/6",
#                 "2019/7/7",
#                 "2019/7/8",
#                 "2019/7/9",
#                 "2019/7/10",
#                 "2019/7/11",
#                 "2019/7/12",
#                 "2019/7/13",
#                 "2019/7/14",
#                 "2019/7/15",
#                 "2019/7/16",
#                 "2019/7

# %% [markdown]
# 【例8-11】仪表盘图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page
c = Gauge()
c.add("业务指标",[("完成率", 55.5)],axisline_opts=opts.AxisLineOpts(
linestyle_opts=opts.LineStyleOpts(color=[(0.3, "#67e0e3"),
 (0.7, "#37a2da"), (1, "#fd666d")], width=30)))
c.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-不同颜色"),
 legend_opts=opts.LegendOpts(is_show=False)) 
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a48a484eee844d6cb503acaf41d2c484" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a48a484eee844d6cb503acaf41d2c484 = echarts.init(
#                     document.getElementById('a48a484eee844d6cb503acaf41d2c484'), 'white', {renderer: 'canvas'});
#                 var option_a48a484eee844d6cb503acaf41d2c484 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "color": "#333",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "backgroundColor": "transparent",
#                 "borderColor": "transparent",
#                 "borderWidth": 0,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 0,
#                 "borderColor": "transparent",
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             },
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Gauge-\u4e0d\u540c\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a48a484eee844d6cb503acaf41d2c484.setOption(option_a48a484eee844d6cb503acaf41d2c484);
#         });
#     </script>

# %% [markdown]
# 【例8-12】词云绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
words = [
    ("牛肉面", 7800),("黄河", 6181),
    ("《读者》杂志", 4386), ("甜胚子", 3055),
    ("甘肃省博物馆", 2055),("莫高窟", 8067),("兰州大学", 4244),
    ("西北师范大学", 1868),("中山桥", 3484),
    ("月牙泉", 1112),("五泉山", 980),
    ("五彩丹霞", 865),("黄河母亲", 847),("崆峒山",678),
    ("羊皮筏子", 1582),("兴隆山",868),
    ("兰州交通大学", 1555),("白塔山", 2550),("五泉山", 2550)]
c = WordCloud()
c.add("", words, word_size_range=[20, 80])
c.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="93a9f557f9dd488d85cd5d56b86cd680" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_93a9f557f9dd488d85cd5d56b86cd680 = echarts.init(
#                     document.getElementById('93a9f557f9dd488d85cd5d56b86cd680'), 'white', {renderer: 'canvas'});
#                 var option_93a9f557f9dd488d85cd5d56b86cd680 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 80
#             ],
#             "data": [
#                 {
#                     "name": "\u725b\u8089\u9762",
#                     "value": 7800,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,119,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u6cb3",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,27,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u300a\u8bfb\u8005\u300b\u6742\u5fd7",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(123,31,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u751c\u80da\u5b50",
#                     "value": 3055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,149,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7518\u8083\u7701\u535a\u7269\u9986",
#                     "value": 2055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,79,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u83ab\u9ad8\u7a9f",
#                     "value": 8067,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,63,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5170\u5dde\u5927\u5b66",
#                     "value": 4244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,45,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u897f\u5317\u5e08\u8303\u5927\u5b66",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,96,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5c71\u6865",
#                     "value": 3484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,142,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u7259\u6cc9",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,108,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u6cc9\u5c71",
#                     "value": 980,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,113,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u5f69\u4e39\u971e",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,60,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u6cb3\u6bcd\u4eb2",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,154,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5d06\u5cd2\u5c71",
#                     "value": 678,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,29,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f8a\u76ae\u7b4f\u5b50",
#                     "value": 1582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,11,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5174\u9686\u5c71",
#                     "value": 868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,59,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5170\u5dde\u4ea4\u901a\u5927\u5b66",
#                     "value": 1555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,130,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u767d\u5854\u5c71",
#                     "value": 2550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,116,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u6cc9\u5c71",
#                     "value": 2550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,97,7)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "always

# %% [markdown]
# 【例8-13】在指定地图上的城市标示某天最高温度。

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
temperature=[30,31,27,29,18]
loc = ['兰州市','天水市','白银市','武威市','甘南藏族自治州']
c =  Map()
c.add("甘肃省", [list(z) for z in zip(loc, temperature)], "甘肃",is_roam=True) 
# is_roam是否开启鼠标缩放和平移漫游
c .set_global_opts(title_opts=opts.TitleOpts(title="甘肃省部分城市最高气温"))
c.render("APP类型.html")
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '甘肃':'https://assets.pyecharts.org/assets/maps/gansu'
#         }
#     });
# </script>
#
#         <div id="792121e99727499fb016b61cea0364f7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '甘肃'], function(echarts) {
#                 var chart_792121e99727499fb016b61cea0364f7 = echarts.init(
#                     document.getElementById('792121e99727499fb016b61cea0364f7'), 'white', {renderer: 'canvas'});
#                 var option_792121e99727499fb016b61cea0364f7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u7518\u8083\u7701",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u7518\u8083",
#             "data": [
#                 {
#                     "name": "\u5170\u5dde\u5e02",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5929\u6c34\u5e02",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u767d\u94f6\u5e02",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u6b66\u5a01\u5e02",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u7518\u5357\u85cf\u65cf\u81ea\u6cbb\u5dde",
#                     "value": 18
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7518\u8083\u7701"
#             ],
#             "selected": {
#                 "\u7518\u8083\u7701": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7518\u8083\u7701\u90e8\u5206\u57ce\u5e02\u6700\u9ad8\u6c14\u6e29",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_792121e99727499fb016b61cea0364f7.setOption(option_792121e99727499fb016b61cea0364f7);
#         });
#     </script>

# %% [markdown]
# 全国主要城市航班流动图为例（虚拟数据）

# %%
from pyecharts import options as opts 
from pyecharts.charts import Geo 
from pyecharts.globals import ChartType, SymbolType

c = (
        Geo()
        .add_schema(maptype="china")
        .add( "",
            [ ("哈尔滨", 66), ("重庆", 88), ("上海", 100), ("乌鲁木齐", 30),("北京", 30),("兰州",170)],
            type_=ChartType.EFFECT_SCATTER,
            color="green",
        )
        .add(
            "geo",
            [("北京", "兰州"),( "兰州","北京"), ("重庆", "杭州"),("哈尔滨", "重庆"),("乌鲁木齐", "哈尔滨")],
            type_=ChartType.LINES,
            effect_opts=opts.EffectOpts(
                symbol=SymbolType.ARROW, symbol_size=6, color="blue"
            ),
            linestyle_opts=opts.LineStyleOpts(curve=0.2),
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="主要城市航班路线和数量"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="49cd9b93220b483a8e5b87ae8dc1d37b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_49cd9b93220b483a8e5b87ae8dc1d37b = echarts.init(
#                     document.getElementById('49cd9b93220b483a8e5b87ae8dc1d37b'), 'white', {renderer: 'canvas'});
#                 var option_49cd9b93220b483a8e5b87ae8dc1d37b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "green",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         88
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         30
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         30
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         170
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 6
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac->\u5170\u5dde",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             103.73,
#                             36.03
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86->\u676d\u5dde",
#                     "coords": [
#                         [
#                             106.551556,
#                             29.563009
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8->\u91cd\u5e86",
#                     "coords": [
#                         [
#                             126.63,
#                             45.75
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50->\u54c8\u5c14\u6ee8",
#                     "coords": [
#                         [
#                             87.68,
#                             43.77
#                         ],
#                         [
#                             126.63,
#                             45.75
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0.2,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 "geo"
#             ],
#             "selected": {
#                 "": true,
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u8981\u57ce\u5e02\u822a\u73ed\u8def\u7ebf\u548c\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_49cd9b93220b483a8e5b87ae8dc1d37b.setOption(option_49cd9b93220b483a8e5b87ae8dc1d37b);
#         });
#     </script>

# %% [markdown]
# 【例8-14】组合图表上下布局。

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line,Scatter
A = ["小米", "三星", "华为", "苹果", "魅族", "VIVO", "OPPO"]
CA = [100,125,87,90,78,98,118]
B = ["草莓", "芒果", "葡萄", "雪梨", "西瓜", "柠檬", "车厘子"]
CB = [78,95,120,102,88,108,98]
bar = Bar()
bar.add_xaxis(A)
bar.add_yaxis("商家A",CA)
bar.add_yaxis("商家B", CB)
bar.set_global_opts(title_opts=opts.TitleOpts(title="Grid-Bar"))
bar.render_notebook()
line=Line()
line.add_xaxis(B)
line.add_yaxis("商家A", CA)
line.add_yaxis("商家B", CB)
line.set_global_opts(title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"),
legend_opts=opts.LegendOpts(pos_top="48%"))
line.render_notebook()
grid = Grid()
grid.add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
grid.add(line, grid_opts=opts.GridOpts(pos_top="60%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="52fd7107af38431488c9c623d464ff18" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_52fd7107af38431488c9c623d464ff18 = echarts.init(
#                     document.getElementById('52fd7107af38431488c9c623d464ff18'), 'white', {renderer: 'canvas'});
#                 var option_52fd7107af38431488c9c623d464ff18 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 100,
#                 125,
#                 87,
#                 90,
#                 78,
#                 98,
#                 118
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 78,
#                 95,
#                 120,
#                 102,
#                 88,
#                 108,
#                 98
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     100
#                 ],
#                 [
#                     "\u8292\u679c",
#                     125
#                 ],
#                 [
#                     "\u8461\u8404",
#                     87
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     90
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     78
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     98
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     118
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     78
#                 ],
#                 [
#                     "\u8292\u679c",
#                     95
#                 ],
#                 [
#                     "\u8461\u8404",
#                     120
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     102
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     88
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     108
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     98
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "top": "48%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO
