# %%
from pyecharts import options as opts
from pyecharts.globals import ThemeType
import numpy as np
# %matplotlib inline

# %%
from pyecharts.charts import Bar
# x轴数据
items = ["相机", "短视频", "视频", "浏览器", "商城", "购票", "小说", "聊天", "小工具", "理财记账"] 
# y轴数据
sum_app = [[5045137.0], [4608092.0], [35723063.0], [23775808.0], [15367847.0], [10424808.0], [76975429.0], [7393185.0], [64636392.0], [50491990.0]]
# 生成实例化对象
bar = Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
bar.add_xaxis([ "总数"])
for item in items:
    bar.add_yaxis(item,sum_app[items.index(item)])
bar.set_global_opts(title_opts=opts.TitleOpts(title="APP类型", subtitle="APP类型"))                 
# bar.render("APP类型.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="22bc56026de54e20b48d9ab8de028b76" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_22bc56026de54e20b48d9ab8de028b76 = echarts.init(
#                     document.getElementById('22bc56026de54e20b48d9ab8de028b76'), 'light', {renderer: 'canvas'});
#                 var option_22bc56026de54e20b48d9ab8de028b76 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u76f8\u673a",
#             "data": [
#                 5045137.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u77ed\u89c6\u9891",
#             "data": [
#                 4608092.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u89c6\u9891",
#             "data": [
#                 35723063.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6d4f\u89c8\u5668",
#             "data": [
#                 23775808.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u57ce",
#             "data": [
#                 15367847.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u8d2d\u7968",
#             "data": [
#                 10424808.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5c0f\u8bf4",
#             "data": [
#                 76975429.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u804a\u5929",
#             "data": [
#                 7393185.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5c0f\u5de5\u5177",
#             "data": [
#                 64636392.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7406\u8d22\u8bb0\u8d26",
#             "data": [
#                 50491990.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f8\u673a",
#                 "\u77ed\u89c6\u9891",
#                 "\u89c6\u9891",
#                 "\u6d4f\u89c8\u5668",
#                 "\u5546\u57ce",
#                 "\u8d2d\u7968",
#                 "\u5c0f\u8bf4",
#                 "\u804a\u5929",
#                 "\u5c0f\u5de5\u5177",
#                 "\u7406\u8d22\u8bb0\u8d26"
#             ],
#             "selected": {
#                 "\u76f8\u673a": true,
#                 "\u77ed\u89c6\u9891": true,
#                 "\u89c6\u9891": true,
#                 "\u6d4f\u89c8\u5668": true,
#                 "\u5546\u57ce": true,
#                 "\u8d2d\u7968": true,
#                 "\u5c0f\u8bf4": true,
#                 "\u804a\u5929": true,
#                 "\u5c0f\u5de5\u5177": true,
#                 "\u7406\u8d22\u8bb0\u8d26": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u603b\u6570"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "APP\u7c7b\u578b",
#             "subtext": "APP\u7c7b\u578b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_22bc56026de54e20b48d9ab8de028b76.setOption(option_22bc56026de54e20b48d9ab8de028b76);
#         });
#     </script>

# %%
from pyecharts.charts import Pie
items = ["相机", "短视频", "视频", "浏览器", "商城", "购票", "小说", "聊天", "小工具", "理财记账"] 
# y轴数据
sum_app = [[5045137.0], [4608092.0], [35723063.0], [23775808.0], [15367847.0], [10424808.0], [76975429.0], [7393185.0], [64636392.0], [50491990.0]]
# 生成实例化对象
pie = Pie(init_opts=opts.InitOpts(theme=ThemeType.INFOGRAPHIC))
pie.add( "",data_pair = 
[(item,sum_app[items.index(item)]) for item in items],    
         radius=["30%", "75%"], 
center=["50%", "50%"],       
rosetype="radius",
label_opts=opts.LabelOpts(is_show=False))
pie.set_global_opts(title_opts = opts.TitleOpts(title="APP比例"))
pie.set_series_opts(label_opts = 
opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#         <div id="f9b5342f48b64655a05686547a78f5a7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'infographic'], function(echarts) {
#                 var chart_f9b5342f48b64655a05686547a78f5a7 = echarts.init(
#                     document.getElementById('f9b5342f48b64655a05686547a78f5a7'), 'infographic', {renderer: 'canvas'});
#                 var option_f9b5342f48b64655a05686547a78f5a7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u76f8\u673a",
#                     "value": [
#                         5045137.0
#                     ]
#                 },
#                 {
#                     "name": "\u77ed\u89c6\u9891",
#                     "value": [
#                         4608092.0
#                     ]
#                 },
#                 {
#                     "name": "\u89c6\u9891",
#                     "value": [
#                         35723063.0
#                     ]
#                 },
#                 {
#                     "name": "\u6d4f\u89c8\u5668",
#                     "value": [
#                         23775808.0
#                     ]
#                 },
#                 {
#                     "name": "\u5546\u57ce",
#                     "value": [
#                         15367847.0
#                     ]
#                 },
#                 {
#                     "name": "\u8d2d\u7968",
#                     "value": [
#                         10424808.0
#                     ]
#                 },
#                 {
#                     "name": "\u5c0f\u8bf4",
#                     "value": [
#                         76975429.0
#                     ]
#                 },
#                 {
#                     "name": "\u804a\u5929",
#                     "value": [
#                         7393185.0
#                     ]
#                 },
#                 {
#                     "name": "\u5c0f\u5de5\u5177",
#                     "value": [
#                         64636392.0
#                     ]
#                 },
#                 {
#                     "name": "\u7406\u8d22\u8bb0\u8d26",
#                     "value": [
#                         50491990.0
#                     ]
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f8\u673a",
#                 "\u77ed\u89c6\u9891",
#                 "\u89c6\u9891",
#                 "\u6d4f\u89c8\u5668",
#                 "\u5546\u57ce",
#                 "\u8d2d\u7968",
#                 "\u5c0f\u8bf4",
#                 "\u804a\u5929",
#                 "\u5c0f\u5de5\u5177",
#                 "\u7406\u8d22\u8bb0\u8d26"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "APP\u6bd4\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f9b5342f48b64655a05686547a78f5a7.setOption(option_f9b5342f48b64655a05686547a78f5a7);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import EffectScatter
from pyecharts.globals import SymbolType
c = (
        EffectScatter()
       .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
     .add_yaxis('商家A', [114, 55, 27, 101, 125, 27, 105])
#        .add_yaxis('商家B',[57, 134, 137, 129, 145, 60, 49])
        .set_global_opts(title_opts=opts.TitleOpts(title="EffectScatter-基本示例"))
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="76c40bc522d4489bbae2c3c468bfb53d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_76c40bc522d4489bbae2c3c468bfb53d = echarts.init(
#                     document.getElementById('76c40bc522d4489bbae2c3c468bfb53d'), 'white', {renderer: 'canvas'});
#                 var option_76c40bc522d4489bbae2c3c468bfb53d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u5546\u5bb6A",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     114
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     55
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     27
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     101
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     125
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     27
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     105
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "EffectScatter-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_76c40bc522d4489bbae2c3c468bfb53d.setOption(option_76c40bc522d4489bbae2c3c468bfb53d);
#         });
#     </script>
